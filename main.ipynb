# %% [markdown]
# <a href="https://colab.research.google.com/github/yanurana/joint-research/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Colab + GitHub!")
# Out:
# Hello Colab + GitHub!
